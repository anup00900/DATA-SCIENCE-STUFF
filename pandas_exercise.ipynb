# %% [markdown]
# **import pandas as pd and numpy as np**

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# read csv from this url https://raw.githubusercontent.com/Kokkalo4/Kaggle-SF-Salaries/master/Salaries.csv using pandas in df variable.
#
#
# If any error is printed ignore that.

# %% [markdown]
# **check the head of DataFrame**

# %%
df.head()
# Out:
#    Id       EmployeeName  ...         Agency Status
# 0   1     NATHANIEL FORD  ...  San Francisco    NaN
# 1   2       GARY JIMENEZ  ...  San Francisco    NaN
# 2   3     ALBERT PARDINI  ...  San Francisco    NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4   5    PATRICK GARDNER  ...  San Francisco    NaN
#
# [5 rows x 13 columns]

# %%
df.head()
# Out:
#    Id       EmployeeName  ...         Agency Status
# 0   1     NATHANIEL FORD  ...  San Francisco    NaN
# 1   2       GARY JIMENEZ  ...  San Francisco    NaN
# 2   3     ALBERT PARDINI  ...  San Francisco    NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4   5    PATRICK GARDNER  ...  San Francisco    NaN
#
# [5 rows x 13 columns]

# %% [markdown]
# **use the info method to find out how many entries there are.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# BasePay and OvertimePay both the fields are of **object** type and contains **missing data**, convert them to numeric using
#
#  `pd.to_numeric(df[column_name], errors='coerce')`
#
#  then check datatype using info function

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors = 'coerce')
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay?**

# %%
d=df['BasePay'].dropna()
print(d)

l = d.tolist()
print(l)
print(type(l[1]))
s=0
for i in range(0,len(l)):
     s=s+l[i]


print(len(df['BasePay']))
avg = s/len(d)
print(avg)

df['BasePay'].mean()
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653         0.00
# Name: BasePay, Length: 148045, dtype: float64
# [167411.18, 155966.02, 212739.13, 77916.0, 134401.6, 118602.0, 92492.01, 256576.96, 176932.64, 285262.0, 194999.39, 99722.0, 294580.02, 271329.03, 174872.64, 198778.01, 268604.57, 140546.87, 168692.63, 257510.59, 257510.48, 257510.44, 140546.88, 168692.63, 140546.86, 256470.41, 92080.8, 168692.59, 261717.6, 246225.6, 234325.02, 254027.63, 248895.7, 104861.39, 177781.25, 101953.2, 245124.44, 110661.2, 132202.26, 147158.85, 168692.66, 168692.63, 218930.76, 123013.02, 196081.86, 249375.02, 168692.64, 248895.77, 233867.6, 137729.92, 168692.59, 246305.62, 140546.87, 140546.88, 140546.89, 226206.8, 240731.93, 217410.8, 115381.02, 214745.44, 123105.0, 102571.24, 140546.86, 168692.62, 148970.43, 185369.69, 177914.76, 139167.39, 122974.0, 115455.44, 220983.12, 92782.61, 95770.8, 233357.28, 130457.88, 85578.61, 174872.64, 73754.05, 140546.88, 168692.62, 172529.08, 122272.69, 168692.62, 230827.12, 217410.8, 122404.98, 150464.82, 96814.36, 88062.0, 138878.82, 188842.37, 102722.4, 149362.84, 215914.03, 168692.62, 215180.76, 208925.6, 168692.67, 122404.98, 224035.85, 168692.65, 123105.0, 105934
# <class 'float'>
# 148654
# 66325.44884050643
# 66325.44884050643

# %%
d
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653         0.00
# Name: BasePay, Length: 148045, dtype: float64

# %% [markdown]
# **What is the highest amount of OvertimePay in the dataset?**

# %%
df['OvertimePay'].max()
# Out:
# 245131.88

# %%
# Out:
# 245131.88

# %% [markdown]
# **What is the Job Title of JOSEPH DRISCOLL?**

# %%
df1 = df.loc[df['EmployeeName']=='JOSEPH DRISCOLL']
df1['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)**

# %%
df1['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# **What is the name of highest paid person**

# %%
r=df['TotalPay'].max()
df2=df.loc[df['TotalPay']==r]
df2['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %% [markdown]
# **What is the name of lowest paid person (including benefits)?**

# %%
r=df['TotalPayBenefits'].min()
df2=df.loc[df['TotalPayBenefits']==r]
df2['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
df2
# Out:
#             Id EmployeeName  ...         Agency  Status
# 148653  148654    Joe Lopez  ...  San Francisco      PT
#
# [1 rows x 13 columns]

# %%
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                      0
# OvertimePay                                  0
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                      PT
# Name: 148653, dtype: object

# %% [markdown]
# drop the column with **0 non-null** value, then print info

# %%
df2=df2.drop(['Notes'],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 148653 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1 non-null      int64
#  1   EmployeeName      1 non-null      object
#  2   JobTitle          1 non-null      object
#  3   BasePay           1 non-null      float64
#  4   OvertimePay       1 non-null      float64
#  5   OtherPay          1 non-null      object
#  6   Benefits          1 non-null      object
#  7   TotalPay          1 non-null      float64
#  8   TotalPayBenefits  1 non-null      float64
#  9   Year              1 non-null      int64
#  10  Agency            1 non-null      object
#  11  Status            1 non-null      object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 104.0+ bytes

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
#  11  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 13.6+ MB

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year?(2011, 2014)**

# %%
g=df.groupby('Year')
g

# %%
for year,year_df in g:
  print(year)
  print(year_df)
  print(year_df['BasePay'].mean())
# Out:
# 2011
#           Id        EmployeeName  ...         Agency  Status
# 0          1      NATHANIEL FORD  ...  San Francisco     NaN
# 1          2        GARY JIMENEZ  ...  San Francisco     NaN
# 2          3      ALBERT PARDINI  ...  San Francisco     NaN
# 3          4   CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4          5     PATRICK GARDNER  ...  San Francisco     NaN
# ...      ...                 ...  ...            ...     ...
# 36154  36155       SERENA HUGHES  ...  San Francisco     NaN
# 36155  36156        JOE BROWN JR  ...  San Francisco     NaN
# 36156  36157      PAULETTE ADAMS  ...  San Francisco     NaN
# 36157  36158       KAUKAB MOHSIN  ...  San Francisco     NaN
# 36158  36159  JOSEPHINE MCCREARY  ...  San Francisco     NaN
#
# [36159 rows x 13 columns]
# 63595.956516774524
# 2012
#           Id        EmployeeName  ...         Agency  Status
# 36159  36160      Gary Altenberg  ...  San Francisco     NaN
# 36160  36161        Gregory Suhr  ...  San Francisco     NaN
# 36161  36162          Khoa Trinh  ...  San Francisco     NaN
# 36162  36163  Joanne Hayes-White  ...  San Francisco     NaN
# 36163  36164   Frederick Binkley  ...  San Francisco     NaN
# ...      ...                 ...  ...            ...     ...
# 72920  72921    Charles Williams  ...  San Francisco     NaN
# 72921  72922        John Carajan  ...  San Francisco     NaN
# 72922  72923         John Draper  ...  San Francisco     NaN
# 72923  72924        Cherise Wong  ...  San Francisco     NaN
# 72924  72925        Donald Clark  ...  San Francisco     NaN
#
# [36766 rows x 13 columns]
# 65436.40685742255
# 2013
#             Id          EmployeeName  ...         Agency  Status
# 72925    72926        Gregory P Suhr  ...  San Francisco     NaN
# 72926    72927  Joanne M Hayes-White  ...  San Francisco     NaN
# 72927    72928           Samson  Lai  ...  San Francisco     NaN
# 72928    72929       Ellen G Moffatt  ...  San Francisco     NaN
# 72929    72930         Robert L Shaw  ...  San Francisco     NaN
# ...        ...                   ...  ...            ...     ...
# 110526  110527        Arthur L Curry  ...  San Francisco     NaN
# 110527  110528         Nereida  Vega  ...  San Francisco     NaN
# 110528  110529      Timothy E Gibson  ...  San Francisco     NaN
# 110529  110530        Mark E Laherty  ...  San Francisco     NaN
# 110530  110531         David P Kucia  ...  San Francisco     NaN
#
# [37606 rows x 13 columns]
# 69630.0302164812
# 2014
#             Id          EmployeeName  ...         Agency  Status
# 110531  110532           David Shinn  ...  San Francisco      PT
# 110532  110533            Amy P Hart  ...  San Francisco      FT
# 110533  110534  William J Coaker Jr.  ...  San Francisco      PT
# 110534  110535        Gregory P Suhr  ...  San Francisco      FT
# 110535  110536  Joanne M Hayes-White  ...  San Francisco      FT
# ...        ...                   ...  ...            ...     ...
# 148649  148650         Roy I Tillery  ...  San Francisco      PT
# 148650  148651          Not provided  ...  San Francisco     NaN
# 148651  148652          Not provided  ...  San Francisco     NaN
# 148652  148653          Not provided  ...  San Francisco     NaN
# 148653  148654             Joe Lopez  ...  San Francisco      PT
#
# [38123 rows x 13 columns]
# 66564.42192449933

# %% [markdown]
# **How many unique job titles are there**

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
# Out:
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**

# %%
df['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# **JobTitles with only one occurence in 2013?**

# %%
df4=df.loc[df['Year']==2013]
(df4['JobTitle'].value_counts()==1).sum()
# Out:
# 202

# %%
# Out:
# 202

# %% [markdown]
# **How many people has word chief in there jobtitle?**

# %%
c=0
for i in df['JobTitle']:
  if 'chief' in i.lower().split(' '):
    c=c+1
print(c)
# Out:
# 477

# %% [markdown]
# **Find correlation of TotalPay with other fields**

# %%
df.corr()
# Out:
#                         Id   BasePay  ...      Year  Notes
# Id                1.000000 -0.204878  ...  0.968171    NaN
# BasePay          -0.204878  1.000000  ...  0.033751    NaN
# OvertimePay      -0.081505  0.266740  ...  0.027887    NaN
# TotalPay         -0.211478  0.954494  ...  0.032090    NaN
# TotalPayBenefits -0.092190  0.946595  ...  0.151947    NaN
# Year              0.968171  0.033751  ...  1.000000    NaN
# Notes                  NaN       NaN  ...       NaN    NaN
#
# [7 rows x 7 columns]

# %%
# Out:
# Id                 -0.211478
# BasePay             0.954494
# OvertimePay         0.504859
# Benefits            0.632202
# TotalPay            1.000000
# TotalPayBenefits    0.977313
# Year                0.032090
# Notes                    NaN
# Name: TotalPay, dtype: float64

# %% [markdown]
# **use np.where and replace 'Not Provided' on Benefit column to `np.nan`, then fill all this nan value with 0**

# %%
df['Notes'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-791cf1d7b075> in <module>()
# ----> 1 df['Notes'].fillna(0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'Notes'

# %%
df4['Notes']=df4['Notes'].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df4
# Out:
#             Id          EmployeeName  ...         Agency  Status
# 72925    72926        Gregory P Suhr  ...  San Francisco     NaN
# 72926    72927  Joanne M Hayes-White  ...  San Francisco     NaN
# 72927    72928           Samson  Lai  ...  San Francisco     NaN
# 72928    72929       Ellen G Moffatt  ...  San Francisco     NaN
# 72929    72930         Robert L Shaw  ...  San Francisco     NaN
# ...        ...                   ...  ...            ...     ...
# 110526  110527        Arthur L Curry  ...  San Francisco     NaN
# 110527  110528         Nereida  Vega  ...  San Francisco     NaN
# 110528  110529      Timothy E Gibson  ...  San Francisco     NaN
# 110529  110530        Mark E Laherty  ...  San Francisco     NaN
# 110530  110531         David P Kucia  ...  San Francisco     NaN
#
# [37606 rows x 13 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37606 entries, 72925 to 110530
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                37606 non-null  int64
#  1   EmployeeName      37606 non-null  object
#  2   JobTitle          37606 non-null  object
#  3   BasePay           37001 non-null  float64
#  4   OvertimePay       37606 non-null  float64
#  5   OtherPay          37606 non-null  object
#  6   Benefits          37606 non-null  object
#  7   TotalPay          37606 non-null  float64
#  8   TotalPayBenefits  37606 non-null  float64
#  9   Year              37606 non-null  int64
#  10  Notes             37606 non-null  float64
#  11  Agency            37606 non-null  object
#  12  Status            0 non-null      object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 4.0+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148654 non-null  object
#  6   Benefits          148654 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 14.7+ MB

# %% [markdown]
# **Now convert Benefit column to numeric type**

# %%
df4['Benefits'] = pd.to_numeric(df4['Benefits'], errors = 'coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37606 entries, 72925 to 110530
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                37606 non-null  int64
#  1   EmployeeName      37606 non-null  object
#  2   JobTitle          37606 non-null  object
#  3   BasePay           37001 non-null  float64
#  4   OvertimePay       37606 non-null  float64
#  5   OtherPay          37606 non-null  object
#  6   Benefits          37606 non-null  float64
#  7   TotalPay          37606 non-null  float64
#  8   TotalPayBenefits  37606 non-null  float64
#  9   Year              37606 non-null  int64
#  10  Notes             37606 non-null  float64
#  11  Agency            37606 non-null  object
#  12  Status            0 non-null      object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 4.0+ MB
